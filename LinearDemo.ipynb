# %% [markdown]
# <a href="https://colab.research.google.com/github/dceaicovschi/untitled/blob/master/LinearDemo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **START TO PRACTICE LINEAR REGRESSION**
# # **EQUATION**
# ![linear.png](data:image/png;base64,...)

# %% [markdown]
# # **Imports**

# %%
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.linear_model import LinearRegression

# %% [markdown]
# # **DATA**

# %%
data = pd.read_csv("dataset.csv")
data
# Out:
#       production_budget_usd  worldwide_gross_usd
# 0                   1000000                   26
# 1                     10000                  401
# 2                    400000                  423
# 3                    750000                  450
# 4                     10000                  527
# ...                     ...                  ...
# 5029              225000000           1519479547
# 5030              215000000           1671640593
# 5031              306000000           2058662225
# 5032              200000000           2207615668
# 5033              425000000           2783918982
#
# [5034 rows x 2 columns]

# %%
data.describe()
# Out:
#        production_budget_usd  worldwide_gross_usd
# count           5.034000e+03         5.034000e+03
# mean            3.290784e+07         9.515685e+07
# std             4.112589e+07         1.726012e+08
# min             1.100000e+03         2.600000e+01
# 25%             6.000000e+06         7.000000e+06
# 50%             1.900000e+07         3.296202e+07
# 75%             4.200000e+07         1.034471e+08
# max             4.250000e+08         2.783919e+09

# %% [markdown]
# # **Visualization**

# %%
plt.figure(figsize=(23, 20))
plt.scatter(data.production_budget_usd, data.worldwide_gross_usd, alpha= 0.4)
plt.xlabel('Budget')
plt.ylabel('Revenue')
plt.ylim(0,3000000000)
plt.xlim(0,450000000)
# Out:
# (0.0, 450000000.0)

# %% [markdown]
# # **Linear Model**

# %%
model= LinearRegression()

# %%
X=pd.DataFrame(data.production_budget_usd) #will predict
Y=pd.DataFrame(data.worldwide_gross_usd)   #should be predicted

# %%
model.fit(X,Y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %% [markdown]
# fit_interceptbool, default=True
#
#     Whether to calculate the intercept for this model. If set to False, no intercept will be used in calculations (i.e. data is expected to be centered).
# normalizebool, default=False
#
#     This parameter is ignored when fit_intercept is set to False. If True, the regressors X will be normalized before regression by subtracting the mean and dividing by the l2-norm. If you wish to standardize, please use StandardScaler before calling fit on an estimator with normalize=False.
# copy_Xbool, default=True
#
#     If True, X will be copied; else, it may be overwritten.
# n_jobsint, default=None
#
#     The number of jobs to use for the computation. This will only provide speedup for n_targets > 1 and sufficient large problems. None means 1 unless in a joblib.parallel_backend context. -1 means using all processors. See Glossary for more details.

# %%
model.coef_  #our incline
# Out:
# array([[3.11150918]])

# %%
model.intercept_ # our lost
# Out:
# array([-7236192.72913958])

# %%
plt.figure(figsize=(23, 20))
plt.scatter(data.production_budget_usd, data.worldwide_gross_usd, alpha= 0.4)

plt.plot(X, model.predict(X), color ='red') #data after pediction

plt.xlabel('Budget')
plt.ylabel('Revenue')
plt.ylim(0,3000000000)
plt.xlim(0,450000000)
# Out:
# (0.0, 450000000.0)

# %%
model.score(X, Y) #score for predict => 1
# Out:
# 0.5496485356985729

# %%
model.predict([[5000000]])
# Out:
# array([[8321353.18554105]])
